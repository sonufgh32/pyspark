# %%
import pandas as pd
import numpy as np
import random
import pyspark.pandas as ps
from pyspark.sql import SparkSession
# Out:
# Starting Spark application
# <table>
# <tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>User</th><th>Current session?</th></tr><tr><td>4</td><td>None</td><td>pyspark</td><td>idle</td><td></td><td></td><td>None</td><td>✔</td></tr></table>
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# SparkSession available as 'spark'.
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
data = [(i, "user_" + str(i), random.randint(18, 60)) for i in range(30)]
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
user = spark.sparkContext.parallelize(data)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
user.collect()
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# [(0, 'user_0', 29), (1, 'user_1', 42), (2, 'user_2', 42), (3, 'user_3', 31), (4, 'user_4', 55), (5, 'user_5', 48), (6, 'user_6', 27), (7, 'user_7', 20), (8, 'user_8', 47), (9, 'user_9', 27), (10, 'user_10', 28), (11, 'user_11', 53), (12, 'user_12', 33), (13, 'user_13', 30), (14, 'user_14', 36), (15, 'user_15', 41), (16, 'user_16', 59), (17, 'user_17', 41), (18, 'user_18', 42), (19, 'user_19', 23), (20, 'user_20', 55), (21, 'user_21', 41), (22, 'user_22', 32), (23, 'user_23', 26), (24, 'user_24', 28), (25, 'user_25', 36), (26, 'user_26', 45), (27, 'user_27', 21), (28, 'user_28', 50), (29, 'user_29', 41)]

# %%
user_df = user.toDF()
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
user_df.show()
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +---+-------+---+
# | _1|     _2| _3|
# +---+-------+---+
# |  0| user_0| 29|
# |  1| user_1| 42|
# |  2| user_2| 42|
# |  3| user_3| 31|
# |  4| user_4| 55|
# |  5| user_5| 48|
# |  6| user_6| 27|
# |  7| user_7| 20|
# |  8| user_8| 47|
# |  9| user_9| 27|
# | 10|user_10| 28|
# | 11|user_11| 53|
# | 12|user_12| 33|
# | 13|user_13| 30|
# | 14|user_14| 36|
# | 15|user_15| 41|
# | 16|user_16| 59|
# | 17|user_17| 41|
# | 18|user_18| 42|
# | 19|user_19| 23|
# +---+-------+---+
# only showing top 20 rows

# %%
df_user = user.toDF(['id', 'username', 'age'])
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
df_user.show()
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +---+--------+---+
# | id|username|age|
# +---+--------+---+
# |  0|  user_0| 29|
# |  1|  user_1| 42|
# |  2|  user_2| 42|
# |  3|  user_3| 31|
# |  4|  user_4| 55|
# |  5|  user_5| 48|
# |  6|  user_6| 27|
# |  7|  user_7| 20|
# |  8|  user_8| 47|
# |  9|  user_9| 27|
# | 10| user_10| 28|
# | 11| user_11| 53|
# | 12| user_12| 33|
# | 13| user_13| 30|
# | 14| user_14| 36|
# | 15| user_15| 41|
# | 16| user_16| 59|
# | 17| user_17| 41|
# | 18| user_18| 42|
# | 19| user_19| 23|
# +---+--------+---+
# only showing top 20 rows

# %%
cols = ("ID", "Username", "Age")
df_users = df_user.toDF(*cols)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
df_users.show(5)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +---+--------+---+
# | ID|Username|Age|
# +---+--------+---+
# |  0|  user_0| 29|
# |  1|  user_1| 42|
# |  2|  user_2| 42|
# |  3|  user_3| 31|
# |  4|  user_4| 55|
# +---+--------+---+
# only showing top 5 rows

# %%
df_user.show(5)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +---+--------+---+
# | id|username|age|
# +---+--------+---+
# |  0|  user_0| 29|
# |  1|  user_1| 42|
# |  2|  user_2| 42|
# |  3|  user_3| 31|
# |  4|  user_4| 55|
# +---+--------+---+
# only showing top 5 rows

# %%
pdf = pd.DataFrame({
    "id": [1, 2, 3],
    "name": ["Alice", "Bob", "Cathy"],
    "age": [25, 30, 28]
})
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
pdf_df = spark.createDataFrame(pdf)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# /home/glue_user/spark/python/pyspark/sql/pandas/conversion.py:474: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for column, series in pdf.iteritems():
# /home/glue_user/spark/python/pyspark/sql/pandas/conversion.py:486: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for column, series in pdf.iteritems():

# %%
pdf_df.show()
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +---+-----+---+
# | id| name|age|
# +---+-----+---+
# |  1|Alice| 25|
# |  2|  Bob| 30|
# |  3|Cathy| 28|
# +---+-----+---+

# %%
pd_pdf_df = pdf_df.toPandas()
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
pd_pdf_df.head()
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
#    id   name  age
# 0   1  Alice   25
# 1   2    Bob   30
# 2   3  Cathy   28

# %%
df = ps.from_pandas(pd_pdf_df)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# /home/glue_user/spark/python/pyspark/pandas/internal.py:1573: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   fields = [
# /home/glue_user/spark/python/pyspark/sql/pandas/conversion.py:486: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for column, series in pdf.iteritems():

# %%
df.head()
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
#    id   name  age
# 0   1  Alice   25
# 1   2    Bob   30
# 2   3  Cathy   28
